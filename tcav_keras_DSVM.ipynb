# %% [markdown]
# ## Run TCAV with Keras

# %% [markdown]
# with code from https://gist.github.com/Gareth001/e600d2fbc09e690c4333388ec5f06587

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import decode_predictions
from keras.models import Model, load_model
import keras.backend as K

import model as tcav_model
import tcav as tcav
import utils as utils
import activation_generator as act_gen
import tensorflow as tf
import utils_plot as utils_plot

#import keras_model as keras_model
# Out:
# /data/anaconda/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input

import numpy as np
from nltk.corpus import wordnet as wn
import os
import operator
from os import listdir
from os.path import isfile, join
import subprocess
from PIL import Image
import requests
from io import BytesIO
import urllib.request

# %%
sess = K.get_session()

# %%
#model = InceptionV3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
#model.save('v3_model.h5')

# %%
tf.logging.set_verbosity(0)

model = None
model = load_model('v3_model.h5')
# Out:
# WARNING:tensorflow:From /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /data/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
endpoints_v3 = dict(
    input=model.inputs[0].name,
    input_tensor=model.inputs[0],
    logit=model.outputs[0].name,
    prediction=model.outputs[0].name,
    prediction_tensor=model.outputs[0],
)

# %%
tf.logging.set_verbosity(0)

label_path = '/home/tyler/Desktop/data/tcav_utils/labels.txt'

mymodel = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], endpoints_v3, 
        'InceptionV3_public', (-1, 1))
# Out:
# WARNING:tensorflow:From /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Making Predictions

# %%
img_path = '/Users/tyler/Desktop/dissertation/programming/tcav/2012_val/val/ILSVRC2012_val_00000001.JPEG'
img_path = '/home/tyler/Desktop/data/images/ceo/img379.jpg'

img = image.load_img(img_path, target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FB9D2E12860>

# %%
img_array = np.array(img)
x = np.expand_dims(img_array, axis=0)
x = preprocess_input(x)

# %%
pred = mymodel.get_predictions(x)
decode_predictions(pred, top=5)
# Out:
# [[('n04350905', 'suit', 0.64607865),
#   ('n10148035', 'groom', 0.046785045),
#   ('n03832673', 'notebook', 0.031221353),
#   ('n04591157', 'Windsor_tie', 0.030615037),
#   ('n03680355', 'Loafer', 0.027136732)]]

# %% [markdown]
# ## Run TCAV

# %%
#print(model.summary())

# %%
working_dir = '/home/tyler/Desktop/data/'
activation_dir =  working_dir + '/tcav_utils/activations/'
cav_dir = working_dir + '/tcav_utils/cavs/'
source_dir = working_dir + '/images'

target = 'zebra'

concepts = ['striped']   

#'mixed0','mixed1', 'mixed2', 'mixed3', 'mixed4', 'mixed5', 'mixed6', 'mixed7', 'mixed8', 'mixed9_0', 'mixed9', 'mixed9_1', 'mixed10']

bottlenecks = ['mixed9']

alphas = [0.1]

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=200)

# %%
tf.logging.set_verbosity(1)

mytcav = tcav.TCAV(sess,
        target, concepts, bottlenecks,
        act_generator, alphas,
        cav_dir = cav_dir,
        num_random_exp=1)
# Out:
# INFO:tensorflow:mixed9 ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:TCAV will 1 params

# %%
results = mytcav.run(run_parallel=True)
# Out:
# INFO:tensorflow:running 1 params
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# ['striped', 'random500_0', 'zebra']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-6dcceb081ded> in <module>()
# ----> 1 results = mytcav.run(run_parallel=True)
#
# /data/home/tyler/Desktop/data/tcav_utils/tcav.py in run(self, num_workers, run_parallel)
#     197     if run_parallel:
#     198       pool = multiprocessing.Pool(num_workers)
# --> 199       results = pool.map(lambda param: self._run_single_set(param), self.params)
#     200     else:
#     201       results = []
#
# /data/anaconda/envs/py35/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /data/anaconda/envs/py35/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /data/anaconda/envs/py35/lib/python3.5/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /data/anaconda/envs/py35/lib/python3.5/multiprocessing/pool.py in mapstar(args)
#      42
#      43 def mapstar(args):
# ---> 44     return list(map(*args))
#      45
#      46 def starmapstar(args):
#
# /data/home/tyler/Desktop/data/tcav_utils/tcav.py in <lambda>(param)
#     197     if run_parallel:
#     198       pool = multiprocessing.Pool(num_workers)
# --> 199       results = pool.map(lambda param: self._run_single_set(param), self.params)
#     200     else:
#     201       results = []
#
# /data/home/tyler/Desktop/data/tcav_utils/tcav.py in _run_single_set(self, param)
#     229     # Get acts
#     230     acts = activation_generator.process_and_load_activations(
# --> 231         [bottleneck], concepts + [target_class])
#     232     # Get CAVs
#     233     cav_hparams = CAV.default_hparams()
#
# /data/home/tyler/Desktop/data/tcav_utils/activation_generator.py in process_and_load_activations(self, bottleneck_names, concepts)
#      84         else:
#      85           acts[concept][bottleneck_name] = self.get_activations_for_concept(
# ---> 86               concept, bottleneck_name)
#      87           if acts_path:
#      88             tf.logging.info('{} does not exist, Making one...'.format(
#
# /data/home/tyler/Desktop/data/tcav_utils/activation_generator.py in get_activations_for_concept(self, concept, bottleneck)
#      59   def get_activations_for_concept(self, concept, bottleneck):
#      60     examples = self.get_examples_for_concept(concept)
# ---> 61     return self.get_activations_for_examples(examples, bottleneck)
#      62
#      63   def get_activations_for_examples(self, examples, bottleneck):
#
# /data/home/tyler/Desktop/data/tcav_utils/activation_generator.py in get_activations_for_examples(self, examples, bottleneck)
#      62
#      63   def get_activations_for_examples(self, examples, bottleneck):
# ---> 64     acts = self.model.run_examples(examples, bottleneck)
#      65     return self.model.reshape_activations(acts).squeeze()
#      66
#
# /data/home/tyler/Desktop/data/tcav_utils/model.py in run_examples(self, examples, bottleneck_name)
#     126     """
#     127     return self.sess.run(self.bottlenecks_tensors[bottleneck_name],
# --> 128                          {self.ends['input']: examples})
#     129
#     130
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126                              'which has shape %r' %
#    1127                              (np_val.shape, subfeed_t.name,
# -> 1128                               str(subfeed_t.get_shape())))
#    1129           if not self.graph.is_feedable(subfeed_t):
#    1130             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (0,) for Tensor 'input_4:0', which has shape '(?, 299, 299, 3)'

# %%
#mymodel.ends

# %%
results
